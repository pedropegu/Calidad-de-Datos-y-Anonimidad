# %% [markdown]
# ## Importar módulos necesarios

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Carga del dataset

# %%
df = pd.read_csv('../Data/Uncleaned_DS_jobs.csv')
df.head()
# Out:
#    index          Job Title               Salary Estimate  \
# 0      0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1      1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2      2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3      3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4      4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#               Company Name       Location            Headquarters  \
# 0         Healthfirst\n3.1   New York, NY            New York, NY
# 1             ManTech\n4.2  Chantilly, VA             Herndon, VA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              672 non-null    int64
#  1   Job Title          672 non-null    object
#  2   Salary Estimate    672 non-null    object
#  3   Job Description    672 non-null    object
#  4   Rating             672 non-null    float64
#  5   Company Name       672 non-null    object
#  6   Location           672 non-null    object
#  7   Headquarters       672 non-null    object
#  8   Size               672 non-null    object
#  9   Founded            672 non-null    int64
#  10  Type of ownership  672 non-null    object
#  11  Industry           672 non-null    object
#  12  Sector             672 non-null    object
#  13  Revenue            672 non-null    object
#  14  Competitors        672 non-null    object
# dtypes: float64(1), int64(2), object(12)
# ...

# %%
df.describe()
# Out:
#             index      Rating      Founded
# count  672.000000  672.000000   672.000000
# mean   335.500000    3.518601  1635.529762
# std    194.133974    1.410329   756.746640
# min      0.000000   -1.000000    -1.000000
# 25%    167.750000    3.300000  1917.750000
# 50%    335.500000    3.800000  1995.000000
# 75%    503.250000    4.300000  2009.000000
# max    671.000000    5.000000  2019.000000

# %% [markdown]
# ## Limpieza de los datos

# %% [markdown]
# Eliminamos columnas innecesarias como el índice y valores duplicados.

# %%
df = df.drop(['index'], axis=1)
df.drop_duplicates(inplace=True)
df
# Out:
#              Job Title               Salary Estimate  \
# 0    Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1       Data Scientist  $137K-$171K (Glassdoor est.)
# 2       Data Scientist  $137K-$171K (Glassdoor est.)
# 3       Data Scientist  $137K-$171K (Glassdoor est.)
# 4       Data Scientist  $137K-$171K (Glassdoor est.)
# ..                 ...                           ...
# 667     Data Scientist  $105K-$167K (Glassdoor est.)
# 668     Data Scientist  $105K-$167K (Glassdoor est.)
# 669     Data Scientist  $105K-$167K (Glassdoor est.)
# 670     Data Scientist  $105K-$167K (Glassdoor est.)
# 671     Data Scientist  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  Rating  \
# 0    Description\n\nThe Senior Data Scientist is re...     3.1
# 1    Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2    Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3    JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# ...

# %% [markdown]
# Analizamos la columna "Company Name" donde encontramos saltos de línea junto a ciertos números.

# %%
df['Company Name']
# Out:
# 0               Healthfirst\n3.1
# 1                   ManTech\n4.2
# 2            Analysis Group\n3.8
# 3                   INFICON\n3.5
# 4        Affinity Solutions\n2.9
#                  ...
# 667                TRANZACT\n3.6
# 668                         JKGT
# 669                   AccessHope
# 670    ChaTeck Incorporated\n5.0
# 671           1-800-Flowers\n2.7
# Name: Company Name, Length: 659, dtype: object

# %% [markdown]
# Seleccionamos la parte que nos interesa que se trata del nombre.

# %%
df['Company Name'] = df['Company Name'].map(lambda x: x.split('\n')[0])
df.head()
# Out:
#            Job Title               Salary Estimate  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# ...

# %% [markdown]
# Remplazamos valores como -1 o Unknown a NA el cual será el valor que reprentará a los valores nulos.

# %%
categorical_cols = ['Job Title', 'Salary Estimate', 'Job Description', 
                    'Company Name', 'Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors']

df[categorical_cols] = df[categorical_cols].replace('-1', 'NA')
df[categorical_cols] = df[categorical_cols].replace('Unknown', 'NA')
df['Rating'] = df['Rating'].replace(-1., 0)

df.head()
# Out:
#            Job Title               Salary Estimate  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# ...

# %% [markdown]
# Verificamos el estado de la columna Salary Estimate donde se observa un rango de valores, para limpiar este campo separaremos el rango y crearemos columnas para el valor de rango mínimo, máximo y para la media.

# %%
df['Salary Estimate'] = df['Salary Estimate'].map(lambda x: x.split('(')[0])

# ELIMINAR LOS RANGOS Y CREAR COLUMNAS CORRESPONDIENTES PARA EL MIN Y EL MAX

df['Min_Salary'] = df['Salary Estimate'].map(lambda x: int(x.split('-')[0].strip('$').replace('K',''))*1000)
df['Max_Salary'] = df['Salary Estimate'].map(lambda x: int(x.split('-')[1].strip('$').replace('K',''))*1000)

df['Avg_Salary'] = (df['Min_Salary'] + df['Max_Salary']) / 2

# %%
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist    $137K-$171K
# 1     Data Scientist    $137K-$171K
# 2     Data Scientist    $137K-$171K
# 3     Data Scientist    $137K-$171K
# 4     Data Scientist    $137K-$171K
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
# ...

# %%
df = df.drop(['Salary Estimate'], axis=1)
df.head()
# Out:
#            Job Title                                    Job Description  \
# 0  Sr Data Scientist  Description\n\nThe Senior Data Scientist is re...
# 1     Data Scientist  Secure our Nation, Ignite your Future\n\nJoin ...
# 2     Data Scientist  Overview\n\n\nAnalysis Group is one of the lar...
# 3     Data Scientist  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4     Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
#
#    Rating        Company Name       Location            Headquarters  \
# 0     3.1         Healthfirst   New York, NY            New York, NY
# 1     4.2             ManTech  Chantilly, VA             Herndon, VA
# 2     3.8      Analysis Group     Boston, MA              Boston, MA
# 3     3.5             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4     2.9  Affinity Solutions   New York, NY            New York, NY
#
#                       Size  Founded        Type of ownership  \
# ...

# %% [markdown]
# Atendiendo a la fecha de fundación de la empresa, este campo simplemente recibirá una limpieza de valores nulos, además añadiremos una columna extra denominada "Company_Age" en la cual tendremos la antigüedad de la empresa desde el año 2024.

# %%
conteo_valores = df['Founded'].unique()
print(conteo_valores)


df['Founded'] = df['Founded'].map(lambda x: x if x > 0 else 0)
df['company_age'] = df['Founded'].map(lambda x: x if x<1 else 2024-x)
conteo_valores = df['Founded'].unique()
print(conteo_valores)
# Out:
# [1993 1968 1981 2000 1998 2010 1996 1990 1983 2014 2012 2016 1965 1973
#  1986 1997 2015 1945 1988 2017 2011 1967 1860 1992 2003 1951 2005 2019
#  1925 2008 1999 1978 1966 1912 1958 2013 1849 1781 1926 2006 1994 1863
#  1995   -1 1982 1974 2001 1985 1913 1971 1911 2009 1959 2007 1939 2002
#  1961 1963 1969 1946 1957 1953 1948 1850 1851 2004 1976 1918 1954 1947
#  1955 2018 1937 1917 1935 1929 1820 1952 1932 1894 1960 1788 1830 1984
#  1933 1880 1887 1970 1942 1980 1989 1908 1853 1875 1914 1898 1956 1977
#  1987 1896 1972 1949 1962]
# [1993 1968 1981 2000 1998 2010 1996 1990 1983 2014 2012 2016 1965 1973
#  1986 1997 2015 1945 1988 2017 2011 1967 1860 1992 2003 1951 2005 2019
#  1925 2008 1999 1978 1966 1912 1958 2013 1849 1781 1926 2006 1994 1863
#  1995    0 1982 1974 2001 1985 1913 1971 1911 2009 1959 2007 1939 2002
#  1961 1963 1969 1946 1957 1953 1948 1850 1851 2004 1976 1918 1954 1947
#  1955 2018 1937 1917 1935 1929 1820 1952 1932 1894 1960 1788 1830 1984
# ...

# %%
df[["Founded","company_age"]].head()
# Out:
#    Founded  company_age
# 0     1993           31
# 1     1968           56
# 2     1981           43
# 3     2000           24
# 4     1998           26

# %% [markdown]
# Limpiaremos los campos de localización y sede central, crearemos un campo same_state que se obtendrá de la siguiente verificación: sede central = localización. Si esta se cumple será 1. Tambíen renombramos el campo de localización y lo dejaremos en Job_State.

# %%
df['Location'] = df['Location'].map(lambda x: x.split(',')[0] if ',' in x else 'NA')
df['Headquarters'] = df['Headquarters'].map(lambda x: x.split(',')[0] if ',' in x else 'NA')

df['job_state'] = df['Location']
df['same_state'] = df.apply(lambda x: 1 if x.Location==x.Headquarters else 0,axis=1)

df.drop(['Location'], axis=1, inplace=True)
df
# Out:
#              Job Title                                    Job Description  \
# 0    Sr Data Scientist  Description\n\nThe Senior Data Scientist is re...
# 1       Data Scientist  Secure our Nation, Ignite your Future\n\nJoin ...
# 2       Data Scientist  Overview\n\n\nAnalysis Group is one of the lar...
# 3       Data Scientist  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4       Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
# ..                 ...                                                ...
# 667     Data Scientist  Summary\n\nWe’re looking for a data scientist ...
# 668     Data Scientist  Job Description\nBecome a thought leader withi...
# 669     Data Scientist  Join a thriving company that is changing the w...
# 670     Data Scientist  100 Remote Opportunity As an AINLP Data Scient...
# 671     Data Scientist  Description\n\nThe Data Scientist will be part...
#
#      Rating          Company Name Headquarters                     Size  \
# ...

# %% [markdown]
# Respecto al título del trabajo, este sufrirá una pequeña limpieza donde nos quedaremos con lo más importante del contenido obviando aquello que es innecesario.

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Data Scientist                                            326
# Data Engineer                                              26
# Senior Data Scientist                                      19
# Machine Learning Engineer                                  15
# Data Analyst                                               12
#                                                          ...
# Data Science Instructor                                     1
# Business Data Analyst                                       1
# Purification Scientist                                      1
# Data Engineer, Enterprise Analytics                         1
# AI/ML - Machine Learning Scientist, Siri Understanding      1
# Name: count, Length: 172, dtype: int64

# %%
df['Job Title'].unique()
# Out:
# array(['Sr Data Scientist', 'Data Scientist',
#        'Data Scientist / Machine Learning Expert',
#        'Staff Data Scientist - Analytics',
#        'Data Scientist - Statistics, Early Career', 'Data Modeler',
#        'Experienced Data Scientist', 'Data Scientist - Contract',
#        'Data Analyst II', 'Medical Lab Scientist',
#        'Data Scientist/Machine Learning', 'Human Factors Scientist',
#        'Business Intelligence Analyst I- Data Insights',
#        'Data Scientist - Risk', 'Data Scientist-Human Resources',
#        'Senior Research Statistician- Data Scientist', 'Data Engineer',
#        'Associate Data Scientist', 'Business Intelligence Analyst',
#        'Senior Analyst/Data Scientist', 'Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst I',
#        'Scientist - Molecular Biology',
#        'Computational Scientist, Machine Learning',
#        'Senior Data Scientist', 'Jr. Data Engineer',
# ...

# %%
def job_title_classifier(title):

    if 'data scientist' in title.lower():
        return 'Data scientist'
    elif 'data engineer' in title.lower():
        return 'Data engineer'
    elif 'analyst' in title.lower():
        return 'Analyst'
    elif 'machine learning' in title.lower():
        return 'MLE'
    elif 'manager' in title.lower():
        return 'Manager'
    elif 'director' in title.lower():
        return 'Director'
    else:
        return 'NA'
    
df['Job_Title_cleaned'] = df['Job Title'].apply(job_title_classifier)
df['Job_Title_cleaned'].value_counts()
# Out:
# Job_Title_cleaned
# Data scientist    444
# NA                 69
# Analyst            55
# Data engineer      46
# MLE                35
# Manager             7
# Director            3
# Name: count, dtype: int64

# %% [markdown]
# Además, crearemos un campo llamado job_level que corresponderá a la experiencia requerida (Este campo lo obtendremos de la columna Job Title).

# %%
def Level_classifier(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr.' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'Senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'Junior'
    else:
        return 'NA'
    
df['Job_Level'] = df['Job Title'].apply(Level_classifier)
df['Job_Level'].value_counts()
# Out:
# Job_Level
# NA        564
# Senior     93
# Junior      2
# Name: count, dtype: int64

# %%
df.drop(['Job Title'], axis=1, inplace=True)
df["Job_Title"] = df["Job_Title_cleaned"]
df.drop(["Job_Title_cleaned"], axis=1, inplace=True)
df.head()
# Out:
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name Headquarters                     Size  Founded  \
# 0         Healthfirst     New York   1001 to 5000 employees     1993
# 1             ManTech      Herndon  5001 to 10000 employees     1968
# 2      Analysis Group       Boston   1001 to 5000 employees     1981
# 3             INFICON    Bad Ragaz    501 to 1000 employees     2000
# 4  Affinity Solutions     New York      51 to 200 employees     1998
#
#          Type of ownership                               Industry  \
# 0   Nonprofit Organization                     Insurance Carriers
# ...

# %% [markdown]
# Comprobamos los valores existentes en el rating y sustituimos valores como los negativo ya que no encajan en este campo.

# %%
df['Rating'].unique()
# Out:
# array([3.1, 4.2, 3.8, 3.5, 2.9, 3.9, 4.4, 3.6, 4.5, 4.7, 3.7, 3.4, 4.1,
#        3.2, 4.3, 2.8, 5. , 4.8, 3.3, 2.7, 2.2, 2.6, 4. , 2.5, 4.9, 2.4,
#        0. , 2.3, 4.6, 3. , 2.1, 2. ])

# %%
df['Rating'].dtype
# Out:
# dtype('float64')

# %%
df['Rating'] = np.where(df.Rating < 0, 0, df.Rating)
df['Rating'].unique()
# Out:
# array([3.1, 4.2, 3.8, 3.5, 2.9, 3.9, 4.4, 3.6, 4.5, 4.7, 3.7, 3.4, 4.1,
#        3.2, 4.3, 2.8, 5. , 4.8, 3.3, 2.7, 2.2, 2.6, 4. , 2.5, 4.9, 2.4,
#        0. , 2.3, 4.6, 3. , 2.1, 2. ])

# %% [markdown]
# El campo de descripción desaparecerá por completo, sin embargo crearemos campos por cada aptitud que se deba necesitar en este. Las aptitudes las podemos establecer echando un vistazo sobre las descripciones, también sabiendo el contexto del dataset puede resultar sencillo obtenerlas.

# %%
df['Job Description'].unique()

# %%
def check_skill(skill, description):
    return 1 if skill.lower() in description.lower() else 0

skills_to_check = ['python','excel','sql','tableau','aws','spark','hadoop','azure']

for skill in skills_to_check:
    df[skill.upper()] = df['Job Description'].apply(lambda x: check_skill(skill, x))

# %%
df.drop(['Job Description'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Rating        Company Name Headquarters                     Size  Founded  \
# 0     3.1         Healthfirst     New York   1001 to 5000 employees     1993
# 1     4.2             ManTech      Herndon  5001 to 10000 employees     1968
# 2     3.8      Analysis Group       Boston   1001 to 5000 employees     1981
# 3     3.5             INFICON    Bad Ragaz    501 to 1000 employees     2000
# 4     2.9  Affinity Solutions     New York      51 to 200 employees     1998
#
#          Type of ownership                               Industry  \
# 0   Nonprofit Organization                     Insurance Carriers
# 1         Company - Public                 Research & Development
# 2  Private Practice / Firm                             Consulting
# 3         Company - Public  Electrical & Electronic Manufacturing
# 4        Company - Private                Advertising & Marketing
#
#               Sector                     Revenue  \
# 0          Insurance    Unknown / Non-Applicable
# ...

# %% [markdown]
# El tamaño de las empresas lo vamos a establecer en diferentes categorías dependiendo de la cantidad de personas que indica que esta tiene. Es decir, eliminaremos los rangos y dejaremos valores categóricos.

# %% [markdown]
# Micro: 1- 10
# Small: 1 - 50
# Middle: 51 - 1000
# Corporate: > 1000

# %%
df['Size'].unique()
# Out:
# array(['1001 to 5000 employees', '5001 to 10000 employees',
#        '501 to 1000 employees', '51 to 200 employees', '10000+ employees',
#        '201 to 500 employees', '1 to 50 employees', 'NA'], dtype=object)

# %%
df['Segment'] = df['Size'].replace({'1 to 50 employees':'Small', '51 to 200 employees':'Middle', '1001 to 5000 employees':'Corporate', '201 to 500 employees':'Middle',
                                                               '10000+ employees':'Corporate','501 to 1000 employees':'Middle', '5001 to 10000 employees':'Corporate','Unknown':'NA','-1':'NA'})
df['Segment'].value_counts()
# Out:
# Segment
# Middle       295
# Corporate    245
# Small         86
# NA            33
# Name: count, dtype: int64

# %%
df.drop(['Size'], axis=1, inplace=True)
df.head()
# Out:
#    Rating        Company Name Headquarters  Founded        Type of ownership  \
# 0     3.1         Healthfirst     New York     1993   Nonprofit Organization
# 1     4.2             ManTech      Herndon     1968         Company - Public
# 2     3.8      Analysis Group       Boston     1981  Private Practice / Firm
# 3     3.5             INFICON    Bad Ragaz     2000         Company - Public
# 4     2.9  Affinity Solutions     New York     1998        Company - Private
#
#                                 Industry             Sector  \
# 0                     Insurance Carriers          Insurance
# 1                 Research & Development  Business Services
# 2                             Consulting  Business Services
# 3  Electrical & Electronic Manufacturing      Manufacturing
# 4                Advertising & Marketing  Business Services
#
#                       Revenue  \
# 0    Unknown / Non-Applicable
# 1      $1 to $2 billion (USD)
# 2  $100 to $500 million (USD)
# ...

# %% [markdown]
# Columnas como el Type of ownership o Industry, podemos dejarlas tal y como están. En el caso de Industry podemos modificarla si quisieramos ya que encontramos muchas categorías que podemos englobar en otras. Además algunas de estas categorías son tan pequeñas que las encontramos menos de 10 veces en el dataset.

# %%
df['Type of ownership'].value_counts()
# Out:
# Type of ownership
# Company - Private                 395
# Company - Public                  153
# Nonprofit Organization             36
# Subsidiary or Business Segment     28
# NA                                 20
# Government                         10
# Other Organization                  5
# Private Practice / Firm             4
# College / University                3
# Self-employed                       2
# Contract                            2
# Hospital                            1
# Name: count, dtype: int64

# %%
df['Industry'].value_counts()
# Out:
# Industry
# Biotech & Pharmaceuticals                   66
# IT Services                                 61
# NA                                          60
# Computer Hardware & Software                56
# Aerospace & Defense                         46
# Enterprise Software & Network Solutions     43
# Consulting                                  38
# Staffing & Outsourcing                      36
# Insurance Carriers                          28
# Internet                                    27
# Advertising & Marketing                     23
# Health Care Services & Hospitals            21
# Research & Development                      17
# Federal Agencies                            16
# Investment Banking & Asset Management       13
# Banks & Credit Unions                        8
# Lending                                      7
# Energy                                       5
# Consumer Products Manufacturing              5
# Telecommunications Services                  5
# ...

# %%
df['Revenue'].value_counts()
# Out:
# Revenue
# Unknown / Non-Applicable            212
# $100 to $500 million (USD)           94
# $10+ billion (USD)                   63
# $2 to $5 billion (USD)               45
# $10 to $25 million (USD)             41
# $1 to $2 billion (USD)               36
# $25 to $50 million (USD)             36
# $1 to $5 million (USD)               31
# $50 to $100 million (USD)            30
# $500 million to $1 billion (USD)     19
# NA                                   16
# $5 to $10 million (USD)              14
# Less than $1 million (USD)           14
# $5 to $10 billion (USD)               8
# Name: count, dtype: int64

# %% [markdown]
# Para finalizar, hemos decidido convertir el nombre de las columnas en minúsculas para que todos los nombres estén formateados. Además ordeno las columnas para que este se pueda observar mejor.

# %%
def columnas_en_mayusculas(df):
    df.columns = map(str.lower, df.columns)
    return df

df = columnas_en_mayusculas(df)
orden_columnas = ['rating', 'company name','headquarters', 'founded', 'company_age',
                'type of ownership', 'industry', 'sector', 'revenue', 'competitors',
                'min_salary', 'max_salary', 'avg_salary', 'job_state', 'same_state',
                'job_title', 'job_level', 'python', 'excel', 'sql', 'tableau',
                'aws', 'spark', 'hadoop', 'azure', 'segment']

df = df[orden_columnas]
df.to_csv('../Data/Cleaned_Data.csv', index=False)

# %% [markdown]
# Comprando valores nulos, al principio del dataset sustituimos aquellos con -1 o unknown por NA. Se contempla la posibilidad de imputar valores pero obseravando los campos en los que estos valores se encuentran no tiene sentido, es mejor dejar "NA" que identifica que el valor es desconocio a "inventar" valores.

# %%
categorical_cols = ['company name','headquarters','type of ownership', 'industry', 'sector', 'revenue', 'competitors',
                'job_state', 'same_state',
                'job_title', 'job_level','segment']
cantidad_na = (df[categorical_cols] == 'NA').sum()
cantidad_na
# Out:
# company name           0
# headquarters          20
# type of ownership     20
# industry              60
# sector                60
# revenue               16
# competitors          488
# job_state             22
# same_state             0
# job_title             69
# job_level            564
# segment               33
# dtype: int64

# %%
na = df.isna().sum()
null = df.isnull().sum()

valores_desconocidos = na + null
valores_desconocidos
# Out:
# rating               0
# company name         0
# headquarters         0
# founded              0
# company_age          0
# type of ownership    0
# industry             0
# sector               0
# revenue              0
# competitors          0
# min_salary           0
# max_salary           0
# avg_salary           0
# job_state            0
# same_state           0
# job_title            0
# job_level            0
# python               0
# excel                0
# sql                  0
# tableau              0
# aws                  0
# spark                0
# hadoop               0
# azure                0
# segment              0
# dtype: int64

# %% [markdown]
# # Diccionario de Campos del Dataset
#
# - **rating**: Calificación: Calificación de la publicación.
# - **company name**: Nombre de la Empresa: Nombre de la empresa.
# - **headquarters**: Sede Central: Ubicación de la sede central.
# - **founded**: Fundación: Año de fundación de la empresa.
# - **company_age**: Edad de la Empresa: Edad de la empresa.
# - **type of ownership**: Tipo de Propiedad: Describe el tipo de empresa (sin fines de lucro, público, privado, etc.).
# - **industry**: Industria: Industria en la que trabaja la empresa.
# - **sector**: Sector: Sector al que pertenece la empresa.
# - **revenue**: Ingresos: Ingresos totales de la empresa.
# - **competitors**: Competidores: Competidores de la empresa.
# - **min_salary**: Salario Mínimo: Salario mínimo para el puesto.
# - **max_salary**: Salario Máximo: Salario máximo para el puesto.
# - **avg_salary**: Salario Promedio: Salario promedio para el puesto.
# - **job_state**: Estado Laboral: Estado donde se encuentra el puesto de trabajo.
# - **same_state**: Mismo Estado: ¿El puesto de trabajo está en el mismo estado que la sede central? (Booleano).
# - **job_title**: Título del Trabajo: Título del puesto de trabajo.
# - **job_level**: Nivel del Trabajo: Nivel del puesto de trabajo.
# - **python**: Python: ¿Se requieren habilidades en Python? (Booleano).
# - **excel**: Excel: ¿Se requieren habilidades en Excel? (Booleano).
# - **sql**: SQL: ¿Se requieren habilidades en SQL? (Booleano).
# - **tableau**: Tableau: ¿Se requieren habilidades en Tableau? (Booleano).
# - **aws**: AWS: ¿Se requieren habilidades en AWS? (Booleano).
# - **spark**: Spark: ¿Se requieren habilidades en Spark? (Booleano).
# - **hadoop**: Hadoop: ¿Se requieren habilidades en Hadoop? (Booleano).
# - **azure**: Azure: ¿Se requieren habilidades en Azure? (Booleano).
# - **segment**: Segmento: Tamaño de la empresa basado en el número de empleados.
#   - Micro: 1-10
#   - Small: 11-50
#   - Middle: 51-1000
#   - Corporate: > 1000
#
# Este diccionario proporciona descripciones para cada uno de los campos del conjunto de datos.
